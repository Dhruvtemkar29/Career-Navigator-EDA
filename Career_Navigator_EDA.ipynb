# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4993a61d-7992-490a-97ef-07b60ed9ca99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4993a61d-7992-490a-97ef-07b60ed9ca99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('education_career_success.csv')
print(df.head(3))
# Out:
#   Student_ID  Age  Gender  High_School_GPA  SAT_Score  University_GPA  \
# 0       S001   22    Male              3.8       1450             3.6
# 1       S002   24  Female              3.6       1380             3.4
# 2       S003   21    Male              3.9       1520             3.8
#
#      Field_of_Study  Internships_Completed  Projects_Completed  \
# 0  Computer Science                      3                   7
# 1          Business                      2                   5
# 2       Engineering                      4                   9
#
#    Certifications  Soft_Skills_Score  Networking_Score  Job_Offers  \
# 0               2                  8                 7           3
# 1               3                  7                 6           2
# 2               4                  9                 8           4
#
#    Starting_Salary  Career_Satisfaction  Years_to_Promotion Current_Job_Level  \
# ...

# %%
rows,column = df.shape
print('Rows :',rows, 'Attributes :', column)
# Out:
# Rows : 400 Attributes : 19

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             400 non-null    object
#  1   Age                    400 non-null    int64
#  2   Gender                 400 non-null    object
#  3   High_School_GPA        400 non-null    float64
#  4   SAT_Score              400 non-null    int64
#  5   University_GPA         400 non-null    float64
#  6   Field_of_Study         400 non-null    object
#  7   Internships_Completed  400 non-null    int64
#  8   Projects_Completed     400 non-null    int64
#  9   Certifications         400 non-null    int64
#  10  Soft_Skills_Score      400 non-null    int64
#  11  Networking_Score       400 non-null    int64
#  12  Job_Offers             400 non-null    int64
#  13  Starting_Salary        400 non-null    int64
# ...

# %%
print(df.columns)
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'High_School_GPA', 'SAT_Score',
#        'University_GPA', 'Field_of_Study', 'Internships_Completed',
#        'Projects_Completed', 'Certifications', 'Soft_Skills_Score',
#        'Networking_Score', 'Job_Offers', 'Starting_Salary',
#        'Career_Satisfaction', 'Years_to_Promotion', 'Current_Job_Level',
#        'Work_Life_Balance', 'Entrepreneurship'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Student_ID               0
# Age                      0
# Gender                   0
# High_School_GPA          0
# SAT_Score                0
# University_GPA           0
# Field_of_Study           0
# Internships_Completed    0
# Projects_Completed       0
# Certifications           0
# Soft_Skills_Score        0
# Networking_Score         0
# Job_Offers               0
# Starting_Salary          0
# Career_Satisfaction      0
# Years_to_Promotion       0
# Current_Job_Level        0
# Work_Life_Balance        0
# Entrepreneurship         0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.nunique())
# Out:
# Student_ID               400
# Age                        5
# Gender                     2
# High_School_GPA            8
# SAT_Score                 35
# University_GPA            13
# Field_of_Study            11
# Internships_Completed      5
# Projects_Completed         8
# Certifications             6
# Soft_Skills_Score          6
# Networking_Score           6
# Job_Offers                 6
# Starting_Salary           63
# Career_Satisfaction        6
# Years_to_Promotion         5
# Current_Job_Level          3
# Work_Life_Balance          5
# Entrepreneurship           1
# dtype: int64

# %%
print(df.describe())
# Out:
#               Age  High_School_GPA    SAT_Score  University_GPA  \
# count  400.000000        400.00000   400.000000      400.000000
# mean    23.000000          3.62425  1388.600000        3.441000
# std      1.415985          0.18795   114.311889        0.285522
# min     21.000000          3.20000  1160.000000        2.800000
# 25%     22.000000          3.50000  1300.000000        3.200000
# 50%     23.000000          3.60000  1380.000000        3.450000
# 75%     24.000000          3.80000  1480.000000        3.700000
# max     25.000000          3.90000  1580.000000        4.000000
#
#        Internships_Completed  Projects_Completed  Certifications  \
# count             400.000000           400.00000        400.0000
# mean                2.500000             6.23500          2.6250
# std                 1.061988             1.90232          1.2702
# min                 0.000000             2.00000          0.0000
# ...

# %%
numerical_cols = df.select_dtypes(
    include=['int64','float64']
).columns

categorical_cols = df.select_dtypes(
    include=['object','category']
).columns

print("Numerical Features:")
print(numerical_cols)

print("\nCategorical Features:")
print(categorical_cols)
# Out:
# Numerical Features:
# Index(['Age', 'High_School_GPA', 'SAT_Score', 'University_GPA',
#        'Internships_Completed', 'Projects_Completed', 'Certifications',
#        'Soft_Skills_Score', 'Networking_Score', 'Job_Offers',
#        'Starting_Salary', 'Career_Satisfaction', 'Years_to_Promotion',
#        'Work_Life_Balance'],
#       dtype='object')
#
# Categorical Features:
# Index(['Student_ID', 'Gender', 'Field_of_Study', 'Current_Job_Level',
#        'Entrepreneurship'],
#       dtype='object')

# %%
for col in df.columns:
    print(f"\n{col}")
    print(df[col].unique())
# Out:
# Student_ID
# ['S001' 'S002' 'S003' 'S004' 'S005' 'S006' 'S007' 'S008' 'S009' 'S010'
#  'S011' 'S012' 'S013' 'S014' 'S015' 'S016' 'S017' 'S018' 'S019' 'S020'
#  'S021' 'S022' 'S023' 'S024' 'S025' 'S026' 'S027' 'S028' 'S029' 'S030'
#  'S031' 'S032' 'S033' 'S034' 'S035' 'S036' 'S037' 'S038' 'S039' 'S040'
#  'S041' 'S042' 'S043' 'S044' 'S045' 'S046' 'S047' 'S048' 'S049' 'S050'
#  'S051' 'S052' 'S053' 'S054' 'S055' 'S056' 'S057' 'S058' 'S059' 'S060'
#  'S061' 'S062' 'S063' 'S064' 'S065' 'S066' 'S067' 'S068' 'S069' 'S070'
#  'S071' 'S072' 'S073' 'S074' 'S075' 'S076' 'S077' 'S078' 'S079' 'S080'
#  'S081' 'S082' 'S083' 'S084' 'S085' 'S086' 'S087' 'S088' 'S089' 'S090'
#  'S091' 'S092' 'S093' 'S094' 'S095' 'S096' 'S097' 'S098' 'S099' 'S100'
#  'S101' 'S102' 'S103' 'S104' 'S105' 'S106' 'S107' 'S108' 'S109' 'S110'
#  'S111' 'S112' 'S113' 'S114' 'S115' 'S116' 'S117' 'S118' 'S119' 'S120'
#  'S121' 'S122' 'S123' 'S124' 'S125' 'S126' 'S127' 'S128' 'S129' 'S130'
# ...

# %%
print(df.corr(numeric_only=True))
# Out:
#                             Age  High_School_GPA  SAT_Score  University_GPA  \
# Age                    1.000000         0.185521   0.177444        0.175435
# High_School_GPA        0.185521         1.000000   0.982396        0.983206
# SAT_Score              0.177444         0.982396   1.000000        0.979050
# University_GPA         0.175435         0.983206   0.979050        1.000000
# Internships_Completed  0.241667         0.949891   0.942034        0.946397
# Projects_Completed     0.204695         0.959775   0.954198        0.960444
# Certifications         0.221561         0.936828   0.935541        0.938113
# Soft_Skills_Score      0.175078         0.965463   0.964108        0.970499
# Networking_Score       0.170544         0.966721   0.964150        0.970358
# Job_Offers             0.238982         0.966361   0.965641        0.965399
# Starting_Salary        0.202366         0.950530   0.952185        0.956360
# ...

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x='month',
    y='passengers',
    data=flights
)

plt.title("Monthly Passenger Distribution")

plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Age', y='Starting_Salary', data=df)
plt.title('Age vs Starting Salary')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y='Starting_Salary', data=df)
plt.title('Boxplot of Starting Salary')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.barplot(
    x='Field_of_Study',
    y='Starting_Salary',
    data=df,
    estimator=np.mean
)
plt.xticks(rotation=45)
plt.title('Average Salary by Field')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Starting_Salary'], bins=20, kde=True)
plt.title('Salary Distribution')
plt.show()

# %%
sns.histplot(df['University_GPA'], bins=15, kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))

numeric_df = df.select_dtypes(include=np.number)

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap')
plt.show()

# %%
cols = [
    'University_GPA',
    'Internships_Completed',
    'Projects_Completed',
    'Networking_Score',
    'Starting_Salary'
]

sns.pairplot(df[cols])
plt.show()

# %%
df.loc[df['Starting_Salary'].idxmax(),
       ['Field_of_Study','Starting_Salary']]
# Out:
# Field_of_Study     Medicine
# Starting_Salary      152000
# Name: 74, dtype: object

# %%
df.loc[df['Starting_Salary'].idxmin()]
# Out:
# Student_ID                S043
# Age                         23
# Gender                    Male
# High_School_GPA            3.2
# SAT_Score                 1190
# University_GPA             2.8
# Field_of_Study            Arts
# Internships_Completed        0
# Projects_Completed           2
# Certifications               0
# Soft_Skills_Score            5
# Networking_Score             4
# Job_Offers                   0
# Starting_Salary          31000
# Career_Satisfaction          5
# Years_to_Promotion           5
# Current_Job_Level        Entry
# Work_Life_Balance            7
# Entrepreneurship            No
# Name: 42, dtype: object

# %%
df.nlargest(
    10,
    'Starting_Salary'
)[['Field_of_Study','Starting_Salary']]
# Out:
#        Field_of_Study  Starting_Salary
# 74           Medicine           152000
# 17           Medicine           150000
# 124          Medicine           150000
# 194          Medicine           150000
# 254          Medicine           150000
# 324          Medicine           150000
# 68           Medicine           148000
# 118  Computer Science           148000
# 164          Medicine           148000
# 188  Computer Science           148000

# %%
df.nsmallest(
    10,
    'Starting_Salary'
)[['Field_of_Study','Starting_Salary']]
# Out:
#     Field_of_Study  Starting_Salary
# 42            Arts            31000
# 64            Arts            31000
# 16            Arts            32000
# 35            Arts            34000
# 55            Arts            34000
# 6             Arts            35000
# 105           Arts            38000
# 175           Arts            38000
# 235           Arts            38000
# 305           Arts            38000

# %%
df['Field_of_Study'].value_counts()
# Out:
# Field_of_Study
# Business            72
# Engineering         58
# Psychology          55
# Computer Science    49
# Law                 44
# Marketing           44
# Medicine            35
# Arts                32
# Finance              5
# Education            3
# Nursing              3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x='University_GPA',
    y='Starting_Salary',
    data=df
)

plt.title('GPA vs Salary')
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')

corr = numeric_df.corr()['Starting_Salary'].sort_values(ascending=False)

print(corr)
# Out:
# Starting_Salary          1.000000
# Job_Offers               0.974087
# Certifications           0.967531
# Career_Satisfaction      0.967181
# University_GPA           0.956360
# Soft_Skills_Score        0.953396
# Networking_Score         0.953012
# SAT_Score                0.952185
# High_School_GPA          0.950530
# Projects_Completed       0.942976
# Internships_Completed    0.937656
# Age                      0.202366
# Work_Life_Balance       -0.852532
# Years_to_Promotion      -0.933113
# Name: Starting_Salary, dtype: float64

# %%
df.groupby('University_GPA')['Starting_Salary'].mean()
sns.scatterplot(
    x='University_GPA',
    y='Starting_Salary',
    data=df
)
# Out:
# <Axes: xlabel='University_GPA', ylabel='Starting_Salary'>

# %%
df.groupby('Internships_Completed')['Starting_Salary'].mean()
# Out:
# Internships_Completed
# 0     34900.000000
# 1     50681.159420
# 2     73981.481481
# 3     93985.401460
# 4    135697.368421
# Name: Starting_Salary, dtype: float64

# %%
df.groupby('Internships_Completed')['Job_Offers'].mean()
# Out:
# Internships_Completed
# 0    0.000000
# 1    1.000000
# 2    2.009259
# 3    3.270073
# 4    4.763158
# Name: Job_Offers, dtype: float64

# %%
df.groupby('Certifications')['Starting_Salary'].mean()
# Out:
# Certifications
# 0     34900.000000
# 1     50681.159420
# 2     74166.666667
# 3     93839.416058
# 4    121269.230769
# 5    143200.000000
# Name: Starting_Salary, dtype: float64

# %%
sns.regplot(
    x='Networking_Score',
    y='Starting_Salary',
    data=df
)
# Out:
# <Axes: xlabel='Networking_Score', ylabel='Starting_Salary'>

# %%
sns.boxplot(
    x='Years_to_Promotion',
    y='Soft_Skills_Score',
    data=df
)
# Out:
# <Axes: xlabel='Years_to_Promotion', ylabel='Soft_Skills_Score'>

# %%
df.groupby('Field_of_Study')['Starting_Salary'].mean().sort_values(ascending=False)
# Out:
# Field_of_Study
# Computer Science    127857.142857
# Medicine            123342.857143
# Engineering          93482.758621
# Finance              87000.000000
# Business             81486.111111
# Law                  80931.818182
# Marketing            80318.181818
# Psychology           69163.636364
# Nursing              67000.000000
# Education            48000.000000
# Arts                 46093.750000
# Name: Starting_Salary, dtype: float64

# %%
df.groupby('Internships_Completed')[['Job_Offers','Starting_Salary']].mean()
# Out:
#                        Job_Offers  Starting_Salary
# Internships_Completed
# 0                        0.000000     34900.000000
# 1                        1.000000     50681.159420
# 2                        2.009259     73981.481481
# 3                        3.270073     93985.401460
# 4                        4.763158    135697.368421

# %%
df[['Networking_Score',
           'Starting_Salary',
           'Job_Offers',
           'Age']].corr()
# Out:
#                   Networking_Score  Starting_Salary  Job_Offers       Age
# Networking_Score          1.000000         0.953012    0.956774  0.170544
# Starting_Salary           0.953012         1.000000    0.974087  0.202366
# Job_Offers                0.956774         0.974087    1.000000  0.238982
# Age                       0.170544         0.202366    0.238982  1.000000

# %%
df[['Starting_Salary',
    'Career_Satisfaction',
    'Work_Life_Balance','University_GPA']].corr()
# Out:
#                      Starting_Salary  Career_Satisfaction  Work_Life_Balance  \
# Starting_Salary             1.000000             0.967181          -0.852532
# Career_Satisfaction         0.967181             1.000000          -0.814488
# Work_Life_Balance          -0.852532            -0.814488           1.000000
# University_GPA              0.956360             0.966918          -0.829506
#
#                      University_GPA
# Starting_Salary            0.956360
# Career_Satisfaction        0.966918
# Work_Life_Balance         -0.829506
# University_GPA             1.000000

# %%
df.groupby('Projects_Completed')['Job_Offers'].mean()

df.groupby('Certifications')['Job_Offers'].mean()
# Out:
# Certifications
# 0    0.000000
# 1    1.000000
# 2    2.018519
# 3    3.262774
# 4    4.307692
# 5    5.000000
# Name: Job_Offers, dtype: float64
